# %%
import pypsa
import pandas as pd
# Out:
# /home/pklein/anaconda3/envs/pypsa-earth/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.13) or chardet (None)/charset_normalizer (3.0.1) doesn't match a supported version!
#   warnings.warn(

# %%
n = pypsa.Network("../networks/elec_s_30.nc")
# Out:
# INFO:pypsa.io:Imported network elec_s_30.nc has buses, carriers, generators, lines, loads, storage_units

# %%
n.lines
# Out:
#           bus0      bus1  num_parallel      length  \
# Line
# 1     ZAF.10_1  ZAF.15_1      1.289474  420.441224
# 2     ZAF.10_1   ZAF.1_1      2.052632  270.877819
# 3     ZAF.10_1   ZAF.2_1      1.000000  503.411365
# 4     ZAF.10_1   ZAF.9_1      0.289474  487.300353
# 5     ZAF.11_1  ZAF.16_1      2.473684  158.863041
# ...        ...       ...           ...         ...
# 60     ZAF.3_1   ZAF.9_1      1.868421  438.803651
# 61     ZAF.4_1   ZAF.7_1      6.921053   37.226238
# 62     ZAF.4_1   ZAF.8_1      2.644737   34.576617
# 63     ZAF.5_1   ZAF.6_1      0.289474  361.104684
# 64     ZAF.7_1   ZAF.8_1      0.578947   45.018516
#
#                              type  s_max_pu         s_nom  capital_cost    x  \
# Line
# 1     Al/St 240/40 4-bundle 380.0       0.7   2189.658631  19972.879329  0.0
# 2     Al/St 240/40 4-bundle 380.0       0.7   3485.579045  12867.934168  0.0
# 3     Al/St 240/40 4-bundle 380.0       0.7   1698.102612  23914.340125  0.0
# ...

# %%
n.plot()
# Out:
# (<matplotlib.collections.PatchCollection at 0x7f552b75d000>,
#  <matplotlib.collections.LineCollection at 0x7f552b750190>)

# %%
map_names={'ZAF.1_1':'EASTERN CAPE',
            'ZAF.2_1':'GAUTENG',
            'ZAF.3_1':'HYDRA CLUSTER',
            'ZAF.4_1':'KZN',
            'ZAF.5_1':'LIMPOPO',
            'ZAF.6_1':'MPUMALANGA',
            'ZAF.7_1':'NORTH WEST',
            'ZAF.8_1':'NORTHERN CAPE',
            'ZAF.9_1':'PELLY',
            'ZAF.10_1':'FREE STATE',
            'ZAF.11_1':'WESTERN CAPE'}

# %%
map_names['ZAF.1_1']
# Out:
# 'EASTERN CAPE'

# %%
for i in range(len(n.lines.index)):
    n.lines.bus0.iloc[i]=map_names[n.lines.bus0.iloc[i]]
    n.lines.bus1.iloc[i]=map_names[n.lines.bus1.iloc[i]]
# Out:
# /tmp/ipykernel_269178/905198349.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n.lines.bus0.iloc[i]=map_names[n.lines.bus0.iloc[i]]
# /tmp/ipykernel_269178/905198349.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   n.lines.bus1.iloc[i]=map_names[n.lines.bus1.iloc[i]]

# %%
n.lines
# Out:
#                bus0           bus1  num_parallel      length  \
# Line
# 1        FREE STATE   EASTERN CAPE      1.000000  661.216517
# 2        FREE STATE        GAUTENG      2.052632  289.017295
# 3        FREE STATE  HYDRA CLUSTER      5.000000  506.473444
# 4        FREE STATE            KZN      0.868421  440.532011
# 5        FREE STATE     MPUMALANGA      5.000000  449.347950
# 6        FREE STATE     NORTH WEST      2.447368  252.778233
# 7        FREE STATE  NORTHERN CAPE      1.763158  453.478172
# 8      WESTERN CAPE  HYDRA CLUSTER      4.289474  640.757856
# 9      WESTERN CAPE  NORTHERN CAPE      1.000000  850.103357
# 10     EASTERN CAPE  HYDRA CLUSTER      2.868421  380.144570
# 11     EASTERN CAPE            KZN      2.157895  693.200167
# 12          GAUTENG     MPUMALANGA     11.657895  234.764394
# 13          GAUTENG     NORTH WEST      6.197368  132.989697
# 14          GAUTENG          PELLY      4.776316  102.646790
# ...

# %%
n.generators.p_nom_opt.groupby(n.generators.carrier).sum()
# Out:
# carrier
# CCGT       2.174034e+01
# OCGT       1.536253e+02
# biomass    1.360000e+01
# coal       3.758943e+04
# load       2.000000e+10
# nuclear    1.813102e+03
# oil        2.140576e+03
# onwind     2.611551e+03
# ror        6.742058e+01
# solar      5.454488e+03
# Name: p_nom_opt, dtype: float64

# %%
n.storage_units.p_nom_opt.groupby(n.storage_units.carrier).sum()
# Out:
# carrier
# PHS      2753.476212
# hydro     592.356688
# Name: p_nom_opt, dtype: float64

# %%
n.links.p_nom_opt.groupby(n.links.carrier).sum()
# Out:
# carrier
# H2 electrolysis       1.047764e-13
# H2 fuel cell          1.495107e-13
# battery charger       1.896001e-13
# battery discharger    2.106667e-13
# Name: p_nom_opt, dtype: float64

# %%
n.stores.e_nom_opt.groupby(n.stores.carrier).sum()
# Out:
# carrier
# H2         2.744907e-13
# battery    1.371323e-14
# Name: e_nom_opt, dtype: float64

# %%
n.loads_t.p_set.sum().sum()/1e6
# Out:
# 0.0

# %%
n.snapshots
# Out:
# DatetimeIndex(['2040-01-01 00:00:00', '2040-01-01 01:00:00',
#                '2040-01-01 02:00:00', '2040-01-01 03:00:00',
#                '2040-01-01 04:00:00', '2040-01-01 05:00:00',
#                '2040-01-01 06:00:00', '2040-01-01 07:00:00',
#                '2040-01-01 08:00:00', '2040-01-01 09:00:00',
#                ...
#                '2040-12-31 14:00:00', '2040-12-31 15:00:00',
#                '2040-12-31 16:00:00', '2040-12-31 17:00:00',
#                '2040-12-31 18:00:00', '2040-12-31 19:00:00',
#                '2040-12-31 20:00:00', '2040-12-31 21:00:00',
#                '2040-12-31 22:00:00', '2040-12-31 23:00:00'],
#               dtype='datetime64[ns]', name='snapshot', length=8784, freq=None)
